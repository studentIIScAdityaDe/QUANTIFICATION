# %%
import pandas as pd
import numpy as np
from datetime import date 

np.random.seed(42)

rows = 65

data = pd.DataFrame({
    "No of frames": np.arange(1, rows + 1),
    "No of projections": [np.nan] * rows,
    "No of Retractions": [np.nan] * rows,
    "Length": [np.nan] * rows,
    "Width": [np.nan] * rows
})

df.loc[0:61, "No of projections"] = np.random.randint(1, 7, size=62)
df.loc[0:61, "No of Retractions"] = np.random.randint(1, 6, size=62)

# Fill rows 62–65 for Length & Width (last 4 rows)
df.loc[61:64, ["Length", "Width"]] = np.random.randint(10, 200, size=(4, 2))


timestamp = date.today().strftime("%Y%m%d")
file_name = f"{timestamp}.xlsx"

df.to_excel(file_name, index= False)

file_name
# Out:
# '20260110.xlsx'

# %%
import pandas as pd
import numpy as np
from datetime import date 

np.random.seed(42)

rows = 65

df = pd.DataFrame({import pandas as pd
import numpy as np
from datetime import date

np.random.s
    "No of frames": np.arange(1, rows + 1),
    "No of projections": [np.nan] * rows,
    "No of Retractions": [np.nan] * rows,
    "Length": [np.nan] * rows,
    "Width": [np.nan] * rows
})

# Heavily weighted towards 1 and 2
projection_values = [1, 2, 3, 4, 5, 6]
projection_probs  = [0.45, 0.35, 0.08, 0.06, 0.04, 0.02]

retraction_values = [1, 2, 3, 4, 5]
retraction_probs  = [0.50, 0.30, 0.10, 0.06, 0.04]

# Fill first 62 rows
df.loc[0:61, "No of projections"] = np.random.choice(
    projection_values, size=62, p=projection_probs
)

df.loc[0:61, "No of Retractions"] = np.random.choice(
    retraction_values, size=62, p=retraction_probs
)

# Fill last 4 rows for Length & Width
df.loc[61:64, ["Length", "Width"]] = np.round(
    np.random.uniform(0.000, 30.000, size=(4, 2)), 4
    )
for col in ["No of projections", "No of Retractions"]:
    df.loc[np.random.choice(rows, 25, replace=False), col] = np.nan

# Save Excel file
timestamp = date.today().strftime("%Y%m%d")
file_name = f"{timestamp}_hcc01_B4.xlsx"
df.to_excel(file_name, index=False)

file_name
# Out:
# '20260111_hcc01_B4.xlsx'
